# %% [markdown]
# # Moving Averages of the High, Low, and Open

# %% [markdown]
# https://www.incrediblecharts.com/indicators/ma_high_low.php

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# yahoo finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = '^nsebank'
start = '2020-01-01'
end = '2023-01-01'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Date
# 2020-01-02 00:00:00+05:30  32133.150391  32465.449219  32121.400391
# 2020-01-03 00:00:00+05:30  32326.949219  32329.800781  31960.400391
# 2020-01-06 00:00:00+05:30  31910.449219  31914.449219  31170.550781
# 2020-01-07 00:00:00+05:30  31598.050781  31851.449219  31200.900391
# 2020-01-08 00:00:00+05:30  30995.500000  31451.849609  30899.550781
#
#                                   Close     Adj Close  Volume
# Date
# 2020-01-02 00:00:00+05:30  32443.849609  32443.472656  253600
# 2020-01-03 00:00:00+05:30  32069.250000  32068.876953  217600
# 2020-01-06 00:00:00+05:30  31237.150391  31236.787109  256200
# 2020-01-07 00:00:00+05:30  31399.400391  31399.035156  294400
# 2020-01-08 00:00:00+05:30  31373.650391  31373.285156  304500

# %%
n = 14 # number of periods
df['MA_High'] = df['High'].rolling(n).mean()
df['MA_Low'] = df['Low'].rolling(n).mean()
df['MA_Open'] = df['Open'].rolling(n).mean()

# %%
df.head(20)
# Out:
#                                    Open          High           Low  \
# Date
# 2020-01-02 00:00:00+05:30  32133.150391  32465.449219  32121.400391
# 2020-01-03 00:00:00+05:30  32326.949219  32329.800781  31960.400391
# 2020-01-06 00:00:00+05:30  31910.449219  31914.449219  31170.550781
# 2020-01-07 00:00:00+05:30  31598.050781  31851.449219  31200.900391
# 2020-01-08 00:00:00+05:30  30995.500000  31451.849609  30899.550781
# 2020-01-09 00:00:00+05:30  31748.250000  32172.699219  31667.150391
# 2020-01-10 00:00:00+05:30  32215.699219  32347.199219  31953.400391
# 2020-01-13 00:00:00+05:30  32139.099609  32322.650391  32074.050781
# 2020-01-14 00:00:00+05:30  32196.449219  32196.449219  31989.199219
# 2020-01-15 00:00:00+05:30  31994.750000  32000.900391  31670.349609
# 2020-01-16 00:00:00+05:30  31810.550781  31988.900391  31692.400391
# 2020-01-17 00:00:00+05:30  31571.650391  31773.550781  31445.500000
# 2020-01-20 00:00:00+05:30  31923.949219  31923.949219  31050.949219
# 2020-01-21 00:00:00+05:30  30978.849609  31171.250000  30858.599609
# 2020-01-22 00:00:00+05:30  31061.599609  31149.050781  30614.000000
# 2020-01-23 00:00:00+05:30  30742.199219  31087.250000  30621.349609
# 2020-01-24 00:00:00+05:30  31040.099609  31375.449219  30879.050781
# 2020-01-27 00:00:00+05:30  31110.550781  31227.050781  30808.550781
# 2020-01-28 00:00:00+05:30  30922.000000  31048.449219  30656.349609
# 2020-01-29 00:00:00+05:30  30915.099609  31082.849609  30835.800781
#
#                                   Close     Adj Close  Volume       MA_High  \
# Date
# 2020-01-02 00:00:00+05:30  32443.849609  32443.472656  253600           NaN
# 2020-01-03 00:00:00+05:30  32069.250000  32068.876953  217600           NaN
# 2020-01-06 00:00:00+05:30  31237.150391  31236.787109  256200           NaN
# 2020-01-07 00:00:00+05:30  31399.400391  31399.035156  294400           NaN
# 2020-01-08 00:00:00+05:30  31373.650391  31373.285156  304500           NaN
# 2020-01-09 00:00:00+05:30  32092.400391  32092.027344  308000           NaN
# 2020-01-10 00:00:00+05:30  32097.400391  32097.027344  444700           NaN
# 2020-01-13 00:00:00+05:30  32177.650391  32177.277344  291400           NaN
# 2020-01-14 00:00:00+05:30  32071.650391  32071.277344  438900           NaN
# 2020-01-15 00:00:00+05:30  31824.900391  31824.531250  545700           NaN
# 2020-01-16 00:00:00+05:30  31853.900391  31853.529297  253700           NaN
# 2020-01-17 00:00:00+05:30  31590.650391  31590.283203  308100           NaN
# 2020-01-20 00:00:00+05:30  31080.650391  31080.289062  282200           NaN
# 2020-01-21 00:00:00+05:30  30947.550781  30947.191406  227500  31993.610491
# 2020-01-22 00:00:00+05:30  30701.449219  30701.091797  200600  31899.582031
# 2020-01-23 00:00:00+05:30  31004.050781  31003.689453  343800  31810.828404
# 2020-01-24 00:00:00+05:30  31241.750000  31241.386719  424600  31772.328404
# 2020-01-27 00:00:00+05:30  30837.400391  30837.041016  309900  31727.728516
# 2020-01-28 00:00:00+05:30  30761.400391  30761.042969  239600  31698.914202
# 2020-01-29 00:00:00+05:30  30877.000000  30876.640625  268800  31621.067801
#
#                                  MA_Low       MA_Open
# Date
# 2020-01-02 00:00:00+05:30           NaN           NaN
# 2020-01-03 00:00:00+05:30           NaN           NaN
# 2020-01-06 00:00:00+05:30           NaN           NaN
# 2020-01-07 00:00:00+05:30           NaN           NaN
# 2020-01-08 00:00:00+05:30           NaN           NaN
# 2020-01-09 00:00:00+05:30           NaN           NaN
# 2020-01-10 00:00:00+05:30           NaN           NaN
# 2020-01-13 00:00:00+05:30           NaN           NaN
# 2020-01-14 00:00:00+05:30           NaN           NaN
# 2020-01-15 00:00:00+05:30           NaN           NaN
# 2020-01-16 00:00:00+05:30           NaN           NaN
# 2020-01-17 00:00:00+05:30           NaN           NaN
# 2020-01-20 00:00:00+05:30           NaN           NaN
# 2020-01-21 00:00:00+05:30  31553.885882  31824.524833
# 2020-01-22 00:00:00+05:30  31446.214425  31747.985491
# 2020-01-23 00:00:00+05:30  31350.567941  31634.789062
# 2020-01-24 00:00:00+05:30  31329.746512  31572.621233
# 2020-01-27 00:00:00+05:30  31301.721540  31537.799805
# 2020-01-28 00:00:00+05:30  31284.350028  31532.549805
# 2020-01-29 00:00:00+05:30  31224.967913  31473.039062

# %%
fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
ax1.plot(df['Adj Close'])
ax1.plot(df['MA_High'], label='Moving Average of High')
ax1.plot(df['MA_Low'], label='Moving Average of Low')
ax1.plot(df['MA_Open'], label='Moving Average of Open')
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')
ax1.legend(loc='best')

ax2 = plt.subplot(2, 1, 2)
ax2.plot(df['MA_High'], label='Moving Average of High')
ax2.plot(df['MA_Low'], label='Moving Average of Low')
ax2.plot(df['MA_Open'], label='Moving Average of Open')
ax2.grid()
ax2.legend(loc='best')
ax2.set_ylabel('Moving Average of High and Low')
ax2.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Candlestick with Moving Averages of the High and Low

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#            Date          Open          High           Low         Close  \
# 0  18262.770833  32133.150391  32465.449219  32121.400391  32443.849609
# 1  18263.770833  32326.949219  32329.800781  31960.400391  32069.250000
# 2  18266.770833  31910.449219  31914.449219  31170.550781  31237.150391
# 3  18267.770833  31598.050781  31851.449219  31200.900391  31399.400391
# 4  18268.770833  30995.500000  31451.849609  30899.550781  31373.650391
#
#       Adj Close  Volume  MA_High  MA_Low  MA_Open  VolumePositive
# 0  32443.472656  253600      NaN     NaN      NaN            True
# 1  32068.876953  217600      NaN     NaN      NaN           False
# 2  31236.787109  256200      NaN     NaN      NaN           False
# 3  31399.035156  294400      NaN     NaN      NaN           False
# 4  31373.285156  304500      NaN     NaN      NaN            True

# %%
from mplfinance.original_flavor import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
candlestick_ohlc(ax1,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax1.plot(df['MA_High'], label='Moving Average of High')
ax1.plot(df['MA_Low'], label='Moving Average of Low')
ax1.plot(df['MA_Open'], label='Moving Average of Open')
ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.grid(True, which='both')
ax1.minorticks_on()
ax1v = ax1.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
ax1v.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
ax1v.axes.yaxis.set_ticklabels([])
ax1v.set_ylim(0, 3*df.Volume.max())
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')
ax1.legend(loc='best')

ax2 = plt.subplot(2, 1, 2)
ax2.plot(df['MA_High'], label='Moving Average of High')
ax2.plot(df['MA_Low'], label='Moving Average of Low')
ax2.plot(df['MA_Open'], label='Moving Average of Open')
ax2.grid()
ax2.legend(loc='best')
ax2.set_ylabel('Moving Average of High and Low')
ax2.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

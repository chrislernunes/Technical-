# %% [markdown]
# # Normalized Average True Range (NATR)

# %% [markdown]
# https://stockcharts.com/school/doku.php?id=chart_school:technical_indicators:average_true_range_atr

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'LT.NS'
start = '2020-01-01'
end = '2023-01-01'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                   Open         High          Low        Close  \
# Date
# 2020-01-01 00:00:00+05:30  1308.400024  1318.900024  1303.000000  1309.949951
# 2020-01-02 00:00:00+05:30  1312.000000  1348.000000  1311.000000  1345.300049
# 2020-01-03 00:00:00+05:30  1344.949951  1344.949951  1330.150024  1335.050049
# 2020-01-06 00:00:00+05:30  1331.000000  1332.000000  1314.099976  1316.750000
# 2020-01-07 00:00:00+05:30  1328.000000  1339.500000  1313.750000  1320.500000
#
#                              Adj Close   Volume
# Date
# 2020-01-01 00:00:00+05:30  1226.583984  3123998
# 2020-01-02 00:00:00+05:30  1259.684326  4335359
# 2020-01-03 00:00:00+05:30  1250.086670  2059871
# 2020-01-06 00:00:00+05:30  1232.951172  2646905
# 2020-01-07 00:00:00+05:30  1236.462402  2077893

# %%
n = 14
df['HL'] = df['High'] - df['Low']
df['HC'] = abs(df['High'] - df['Adj Close'].shift())
df['LC'] = abs(df['Low'] - df['Adj Close'].shift())
df['TR'] = df[['HL','HC','LC']].max(axis=1)
df['ATR'] = df['TR'].rolling(n).mean()
df['NATR'] = df['ATR'].shift(n)/df['Adj Close'].shift(n) * 100
df = df.drop(['HL','HC','LC','TR','ATR'],axis=1)

# %%
df.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2022-12-26 00:00:00+05:30  2052.750000  2108.000000  2051.000000  2091.050049
# 2022-12-27 00:00:00+05:30  2101.550049  2128.000000  2085.000000  2124.100098
# 2022-12-28 00:00:00+05:30  2129.000000  2136.000000  2113.649902  2121.100098
# 2022-12-29 00:00:00+05:30  2109.649902  2120.550049  2094.149902  2110.899902
# 2022-12-30 00:00:00+05:30  2115.000000  2133.000000  2081.100098  2085.800049
#
#                              Adj Close   Volume      NATR
# Date
# 2022-12-26 00:00:00+05:30  2091.050049  1154610  1.637382
# 2022-12-27 00:00:00+05:30  2124.100098  1059351  1.588983
# 2022-12-28 00:00:00+05:30  2121.100098  1153883  1.592867
# 2022-12-29 00:00:00+05:30  2110.899902  1517150  1.705260
# 2022-12-30 00:00:00+05:30  2085.800049  1189427  1.739745

# %%
fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
ax1.plot(df['Adj Close'])
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')
ax1.legend(loc='best')

ax2 = plt.subplot(2, 1, 2)
ax2.plot(df['NATR'], label='NATR')
ax2.axhline(y=1, color='black')
ax2.grid()
ax2.legend(loc='best')
ax2.set_ylabel('Normalized Average True Range')
ax2.set_xlabel('Date')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Candlestick with NATR

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#            Date         Open         High          Low        Close  \
# 0  18261.770833  1308.400024  1318.900024  1303.000000  1309.949951
# 1  18262.770833  1312.000000  1348.000000  1311.000000  1345.300049
# 2  18263.770833  1344.949951  1344.949951  1330.150024  1335.050049
# 3  18266.770833  1331.000000  1332.000000  1314.099976  1316.750000
# 4  18267.770833  1328.000000  1339.500000  1313.750000  1320.500000
#
#      Adj Close   Volume  NATR  VolumePositive
# 0  1226.583984  3123998   NaN           False
# 1  1259.684326  4335359   NaN           False
# 2  1250.086670  2059871   NaN           False
# 3  1232.951172  2646905   NaN           False
# 4  1236.462402  2077893   NaN           False

# %%
from mpl_finance import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
candlestick_ohlc(ax1,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.grid(True, which='both')
ax1.minorticks_on()
ax1v = ax1.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
ax1v.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
ax1v.axes.yaxis.set_ticklabels([])
ax1v.set_ylim(0, 3*df.Volume.max())
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')

ax2 = plt.subplot(2, 1, 2)
ax2.plot(df['NATR'], label='NATR')
ax2.axhline(y=1, color='black')
ax2.grid()
ax2.legend(loc='best')
ax2.set_ylabel('Average True Range')
ax2.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# # Moving Linear Regression

# %% [markdown]
# https://www.fmlabs.com/reference/default.htm

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol1 = 'hdfcbank.ns'
symbol2 = 'sbin.ns'
start = '2020-01-01'
end = '2023-01-01'

# Read data 
df1 = yf.download(symbol1,start,end)
df2 = yf.download(symbol2,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# View Columns
df1.head()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2020-01-01 00:00:00+05:30  1276.099976  1280.000000  1270.599976  1278.599976
# 2020-01-02 00:00:00+05:30  1279.000000  1288.000000  1279.000000  1286.750000
# 2020-01-03 00:00:00+05:30  1282.199951  1285.000000  1263.599976  1268.400024
# 2020-01-06 00:00:00+05:30  1260.000000  1261.800049  1236.000000  1240.949951
# 2020-01-07 00:00:00+05:30  1258.900024  1271.449951  1252.250000  1260.599976
#
#                              Adj Close   Volume
# Date
# 2020-01-01 00:00:00+05:30  1258.458008  1836849
# 2020-01-02 00:00:00+05:30  1266.479614  3068583
# 2020-01-03 00:00:00+05:30  1248.418701  5427775
# 2020-01-06 00:00:00+05:30  1221.401001  5445093
# 2020-01-07 00:00:00+05:30  1240.741455  7362247

# %%
df2.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-01 00:00:00+05:30  334.700012  335.950012  332.149994  334.450012
# 2020-01-02 00:00:00+05:30  334.500000  339.850006  333.350006  339.299988
# 2020-01-03 00:00:00+05:30  337.950012  337.950012  332.000000  333.700012
# 2020-01-06 00:00:00+05:30  331.700012  331.700012  317.700012  319.000000
# 2020-01-07 00:00:00+05:30  324.450012  327.000000  315.399994  318.399994
#
#                             Adj Close    Volume
# Date
# 2020-01-01 00:00:00+05:30  326.298218  17379320
# 2020-01-02 00:00:00+05:30  331.029968  20324236
# 2020-01-03 00:00:00+05:30  325.566467  21853208
# 2020-01-06 00:00:00+05:30  311.224762  35645325
# 2020-01-07 00:00:00+05:30  310.639374  50966826

# %%
avg1 = df1['Adj Close'].mean()
avg2 = df2['Adj Close'].mean()
df1['AVGS1_S1'] = avg1 - df1['Adj Close']
df1['AVGS2_S2'] = avg2 - df2['Adj Close']
df1['Average_SQ'] = df1['AVGS1_S1']**2
df1['AVG_AVG'] = df1['AVGS1_S1']*df1['AVGS2_S2']

# %%
df1.head(20)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2020-01-01 00:00:00+05:30  1276.099976  1280.000000  1270.599976  1278.599976
# 2020-01-02 00:00:00+05:30  1279.000000  1288.000000  1279.000000  1286.750000
# 2020-01-03 00:00:00+05:30  1282.199951  1285.000000  1263.599976  1268.400024
# 2020-01-06 00:00:00+05:30  1260.000000  1261.800049  1236.000000  1240.949951
# 2020-01-07 00:00:00+05:30  1258.900024  1271.449951  1252.250000  1260.599976
# 2020-01-08 00:00:00+05:30  1246.949951  1262.150024  1240.050049  1257.300049
# 2020-01-09 00:00:00+05:30  1265.000000  1275.800049  1263.099976  1271.400024
# 2020-01-10 00:00:00+05:30  1284.099976  1286.900024  1275.099976  1282.699951
# 2020-01-13 00:00:00+05:30  1282.699951  1296.500000  1276.000000  1286.000000
# 2020-01-14 00:00:00+05:30  1289.000000  1292.550049  1277.500000  1289.500000
# 2020-01-15 00:00:00+05:30  1286.400024  1287.949951  1274.099976  1284.250000
# 2020-01-16 00:00:00+05:30  1282.050049  1291.000000  1279.349976  1287.650024
# 2020-01-17 00:00:00+05:30  1281.750000  1284.900024  1271.900024  1278.150024
# 2020-01-20 00:00:00+05:30  1304.849976  1304.849976  1252.500000  1254.900024
# 2020-01-21 00:00:00+05:30  1250.000000  1250.000000  1238.400024  1244.349976
# 2020-01-22 00:00:00+05:30  1248.050049  1255.000000  1234.400024  1240.849976
# 2020-01-23 00:00:00+05:30  1240.000000  1246.849976  1231.000000  1244.849976
# 2020-01-24 00:00:00+05:30  1246.000000  1254.000000  1239.099976  1244.550049
# 2020-01-27 00:00:00+05:30  1235.000000  1235.000000  1211.750000  1213.199951
# 2020-01-28 00:00:00+05:30  1218.800049  1227.800049  1213.250000  1223.199951
#
#                              Adj Close    Volume    AVGS1_S1   AVGS2_S2  \
# Date
# 2020-01-01 00:00:00+05:30  1258.458008   1836849   92.809769  54.437919
# 2020-01-02 00:00:00+05:30  1266.479614   3068583   84.788163  49.706169
# 2020-01-03 00:00:00+05:30  1248.418701   5427775  102.849076  55.169670
# 2020-01-06 00:00:00+05:30  1221.401001   5445093  129.866776  69.511375
# 2020-01-07 00:00:00+05:30  1240.741455   7362247  110.526322  70.096763
# 2020-01-08 00:00:00+05:30  1237.493530   5666055  113.774247  68.730888
# 2020-01-09 00:00:00+05:30  1251.371460   4773158   99.896317  58.584343
# 2020-01-10 00:00:00+05:30  1262.493286   4607290   88.774491  56.584343
# 2020-01-13 00:00:00+05:30  1265.741333   3725784   85.526444  58.047752
# 2020-01-14 00:00:00+05:30  1269.186279   3943145   82.081498  60.730766
# 2020-01-15 00:00:00+05:30  1264.018921   5893724   87.248856  64.389335
# 2020-01-16 00:00:00+05:30  1267.365356   3575200   83.902421  65.316185
# 2020-01-17 00:00:00+05:30  1258.015015   8459407   93.252763  70.486992
# 2020-01-20 00:00:00+05:30  1235.131348  11089225  116.136430  74.389488
# 2020-01-21 00:00:00+05:30  1224.747559   7492402  126.520219  74.682182
# 2020-01-22 00:00:00+05:30  1221.302612   9184155  129.965165  72.291923
# 2020-01-23 00:00:00+05:30  1225.239624   5754460  126.028153  65.413749
# 2020-01-24 00:00:00+05:30  1224.944458   5915878  126.323319  64.584495
# 2020-01-27 00:00:00+05:30  1194.088135   9444276  157.179642  72.243126
# 2020-01-28 00:00:00+05:30  1203.930542   6706079  147.337235  73.316307
#
#                              Average_SQ       AVG_AVG
# Date
# 2020-01-01 00:00:00+05:30   8613.653302   5052.370737
# 2020-01-02 00:00:00+05:30   7189.032583   4214.494741
# 2020-01-03 00:00:00+05:30  10577.932449   5674.149563
# 2020-01-06 00:00:00+05:30  16865.379578   9027.218197
# 2020-01-07 00:00:00+05:30  12216.067892   7747.537440
# 2020-01-08 00:00:00+05:30  12944.579274   7819.805029
# 2020-01-09 00:00:00+05:30   9979.274207   5852.360078
# 2020-01-10 00:00:00+05:30   7880.910272   5023.246221
# 2020-01-13 00:00:00+05:30   7314.772664   4964.617828
# 2020-01-14 00:00:00+05:30   6737.372305   4984.872241
# 2020-01-15 00:00:00+05:30   7612.362934   5617.895865
# 2020-01-16 00:00:00+05:30   7039.616216   5480.186010
# 2020-01-17 00:00:00+05:30   8696.077732   6573.106689
# 2020-01-20 00:00:00+05:30  13487.670278   8639.329522
# 2020-01-21 00:00:00+05:30  16007.365728   9448.805993
# 2020-01-22 00:00:00+05:30  16890.944098   9395.431721
# 2020-01-23 00:00:00+05:30  15883.095404   8243.974027
# 2020-01-24 00:00:00+05:30  15957.580983   8158.527806
# 2020-01-27 00:00:00+05:30  24705.440010  11355.148650
# 2020-01-28 00:00:00+05:30  21708.260892  10802.221933

# %%
sum_sq = df1['Average_SQ'].sum()
sum_avg = df1['AVG_AVG'].sum()
slope = sum_avg/sum_sq
intercept = avg2-(slope*avg1)

# %%
df1['Linear_Regression'] = intercept + slope*(df1['Adj Close'])

# %%
n = 14 # number of periods
df1['Moving_Linear_Regression'] = df1['Linear_Regression'].rolling(n).mean()

# %%
df1 = df1.drop(['AVGS1_S1', 'AVGS2_S2', 'Average_SQ', 'AVG_AVG'], axis=1)
df1.head()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2020-01-01 00:00:00+05:30  1276.099976  1280.000000  1270.599976  1278.599976
# 2020-01-02 00:00:00+05:30  1279.000000  1288.000000  1279.000000  1286.750000
# 2020-01-03 00:00:00+05:30  1282.199951  1285.000000  1263.599976  1268.400024
# 2020-01-06 00:00:00+05:30  1260.000000  1261.800049  1236.000000  1240.949951
# 2020-01-07 00:00:00+05:30  1258.900024  1271.449951  1252.250000  1260.599976
#
#                              Adj Close   Volume  Linear_Regression  \
# Date
# 2020-01-01 00:00:00+05:30  1258.458008  1836849         330.752908
# 2020-01-02 00:00:00+05:30  1266.479614  3068583         335.072990
# 2020-01-03 00:00:00+05:30  1248.418701  5427775         325.346183
# 2020-01-06 00:00:00+05:30  1221.401001  5445093         310.795647
# 2020-01-07 00:00:00+05:30  1240.741455  7362247         321.211558
#
#                            Moving_Linear_Regression
# Date
# 2020-01-01 00:00:00+05:30                       NaN
# 2020-01-02 00:00:00+05:30                       NaN
# 2020-01-03 00:00:00+05:30                       NaN
# 2020-01-06 00:00:00+05:30                       NaN
# 2020-01-07 00:00:00+05:30                       NaN

# %%
fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
ax1.plot(df1['Adj Close'])
ax1.plot(df1['Linear_Regression'], label='Linear_Regression')
ax1.plot(df1['Moving_Linear_Regression'], label='Moving_Linear_Regression')
ax1.set_title('Stock '+ symbol1 +' Closing Price')
ax1.set_ylabel('Price')
ax1.legend(loc='best')

ax2 = plt.subplot(2, 1, 2)
df1['VolumePositive'] = df1['Open'] < df1['Adj Close']
colors = df1.VolumePositive.map({True: 'g', False: 'r'})
ax2.bar(df1.index, df1['Volume'], color=colors, alpha=0.4)
ax2.grid()
ax2.set_ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %% [markdown]
# ## Candlestick with Moving Linear Regression

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df1.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#            Date         Open         High          Low        Close  \
# 0  18261.770833  1276.099976  1280.000000  1270.599976  1278.599976
# 1  18262.770833  1279.000000  1288.000000  1279.000000  1286.750000
# 2  18263.770833  1282.199951  1285.000000  1263.599976  1268.400024
# 3  18266.770833  1260.000000  1261.800049  1236.000000  1240.949951
# 4  18267.770833  1258.900024  1271.449951  1252.250000  1260.599976
#
#      Adj Close   Volume  Linear_Regression  Moving_Linear_Regression  \
# 0  1258.458008  1836849         330.752908                       NaN
# 1  1266.479614  3068583         335.072990                       NaN
# 2  1248.418701  5427775         325.346183                       NaN
# 3  1221.401001  5445093         310.795647                       NaN
# 4  1240.741455  7362247         321.211558                       NaN
#
#    VolumePositive
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False

# %%
from mpl_finance import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
candlestick_ohlc(ax1,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax1.plot(df1['Linear_Regression'], label='Linear_Regression')
ax1.plot(df1['Moving_Linear_Regression'], label='Moving_Linear_Regression')
ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.grid(True, which='both')
ax1.minorticks_on()
ax1v = ax1.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
ax1v.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
ax1v.axes.yaxis.set_ticklabels([])
ax1v.set_ylim(0, 3*df1.Volume.max())
ax1.set_title('Stock '+ symbol1 +' Closing Price')
ax1.set_ylabel('Price')
ax1.legend(loc='best')

ax2 = plt.subplot(2, 1, 2)
df1['VolumePositive'] = df1['Open'] < df1['Adj Close']
colors = df1.VolumePositive.map({True: 'g', False: 'r'})
ax2.bar(df1.index, df1['Volume'], color=colors, alpha=0.4)
ax2.grid()
ax2.set_ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

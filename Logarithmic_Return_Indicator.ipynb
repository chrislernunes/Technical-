# %% [markdown]
# # Logarithmic Return Indicator

# %% [markdown]
# https://www.investopedia.com/terms/l/logarithmicscale.asp

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# yahoo finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'wipro.ns'
start = '2020-01-01'
end = '2023-01-01'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Date
# 2020-01-01 00:00:00+05:30  246.500000  248.649994  246.199997  247.699997
# 2020-01-02 00:00:00+05:30  246.600006  249.899994  246.350006  248.300003
# 2020-01-03 00:00:00+05:30  249.500000  252.699997  247.350006  251.100006
# 2020-01-06 00:00:00+05:30  251.000000  254.449997  250.149994  252.149994
# 2020-01-07 00:00:00+05:30  253.250000  256.350006  250.199997  255.199997
#
#                             Adj Close   Volume
# Date
# 2020-01-01 00:00:00+05:30  243.122711  1413866
# 2020-01-02 00:00:00+05:30  243.711609  1443966
# 2020-01-03 00:00:00+05:30  246.459869  3381404
# 2020-01-06 00:00:00+05:30  247.490448  4566695
# 2020-01-07 00:00:00+05:30  250.484100  4402787

# %%
n = 10
df['Logarithmic_Return'] = np.log(df['Adj Close']) - np.log(df['Adj Close'].shift(1))

# %%
df.head(20)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-01 00:00:00+05:30  246.500000  248.649994  246.199997  247.699997
# 2020-01-02 00:00:00+05:30  246.600006  249.899994  246.350006  248.300003
# 2020-01-03 00:00:00+05:30  249.500000  252.699997  247.350006  251.100006
# 2020-01-06 00:00:00+05:30  251.000000  254.449997  250.149994  252.149994
# 2020-01-07 00:00:00+05:30  253.250000  256.350006  250.199997  255.199997
# 2020-01-08 00:00:00+05:30  254.000000  256.149994  252.550003  254.800003
# 2020-01-09 00:00:00+05:30  254.250000  256.500000  252.649994  253.649994
# 2020-01-10 00:00:00+05:30  253.949997  255.199997  251.000000  251.750000
# 2020-01-13 00:00:00+05:30  254.000000  257.899994  252.850006  254.800003
# 2020-01-14 00:00:00+05:30  256.850006  258.350006  254.550003  257.200012
# 2020-01-15 00:00:00+05:30  254.000000  256.000000  246.600006  248.250000
# 2020-01-16 00:00:00+05:30  248.000000  252.600006  247.000000  250.449997
# ...

# %%
fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
ax1.plot(df['Adj Close'])
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')

ax2 = plt.subplot(2, 1, 2)
ax2.plot(df['Logarithmic_Return'], label='Logarithmic Return', color='red')
#ax2.axhline(y=0, color='blue', linestyle='--')
#ax2.axhline(y=0.5, color='darkblue')
#ax2.axhline(y=-0.5, color='darkblue')
ax2.grid()
ax2.set_ylabel('Logarithmic Return')
ax2.set_xlabel('Date')
ax2.legend(loc='best')

# %% [markdown]
# ## Candlestick with  Logarithmic Return

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0  18261.770833  246.500000  248.649994  246.199997  247.699997  243.122711
# 1  18262.770833  246.600006  249.899994  246.350006  248.300003  243.711609
# 2  18263.770833  249.500000  252.699997  247.350006  251.100006  246.459869
# 3  18266.770833  251.000000  254.449997  250.149994  252.149994  247.490448
# 4  18267.770833  253.250000  256.350006  250.199997  255.199997  250.484100
#
#     Volume  Logarithmic_Return  VolumePositive
# 0  1413866                 NaN           False
# 1  1443966            0.002419           False
# 2  3381404            0.011214           False
# 3  4566695            0.004173           False
# 4  4402787            0.012023           False

# %%
from mpl_finance import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
candlestick_ohlc(ax1,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.grid(True, which='both')
ax1.minorticks_on()
ax1v = ax1.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
ax1v.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
ax1v.axes.yaxis.set_ticklabels([])
ax1v.set_ylim(0, 3*df.Volume.max())
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')

ax2 = plt.subplot(2, 1, 2)
ax2.plot(df['Logarithmic_Return'], label='Logarithmic Return', color='red')
#ax2.axhline(y=0, color='blue', linestyle='--')
#ax2.axhline(y=0.5, color='darkblue')
#ax2.axhline(y=-0.5, color='darkblue')
ax2.grid()
ax2.set_ylabel('Logarithmic Return')
ax2.set_xlabel('Date')
ax2.legend(loc='best')

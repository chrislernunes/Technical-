# %% [markdown]
# # Moving Minimum Price

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'kotakbank.ns'
start = '2020-01-01'
end = '2023-01-01'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                   Open         High          Low        Close  \
# Date
# 2020-01-01 00:00:00+05:30  1689.000000  1696.750000  1672.000000  1674.050049
# 2020-01-02 00:00:00+05:30  1680.000000  1683.500000  1664.650024  1671.550049
# 2020-01-03 00:00:00+05:30  1670.949951  1673.000000  1645.550049  1657.099976
# 2020-01-06 00:00:00+05:30  1657.099976  1657.449951  1638.599976  1652.550049
# 2020-01-07 00:00:00+05:30  1661.050049  1674.750000  1650.400024  1670.849976
#
#                              Adj Close   Volume
# Date
# 2020-01-01 00:00:00+05:30  1672.212524  1475056
# 2020-01-02 00:00:00+05:30  1669.715210  1852089
# 2020-01-03 00:00:00+05:30  1655.281006  1594089
# 2020-01-06 00:00:00+05:30  1650.736084  1480087
# 2020-01-07 00:00:00+05:30  1669.015991  2497931

# %%
n = 14
df['Minimum_Price'] = df['Adj Close'].rolling(14).min()
df['Moving_Minimum'] = df['Minimum_Price'].rolling(n).min()

# %%
plt.figure(figsize=(14,8))
plt.plot(df['Adj Close'])
plt.plot(df['Moving_Minimum'], color='red')
plt.title('Moving Minimum Price Indicator of Stock')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Candlestick with Minimum Price

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#            Date         Open         High          Low        Close  \
# 0  18261.770833  1689.000000  1696.750000  1672.000000  1674.050049
# 1  18262.770833  1680.000000  1683.500000  1664.650024  1671.550049
# 2  18263.770833  1670.949951  1673.000000  1645.550049  1657.099976
# 3  18266.770833  1657.099976  1657.449951  1638.599976  1652.550049
# 4  18267.770833  1661.050049  1674.750000  1650.400024  1670.849976
#
#      Adj Close   Volume  Minimum_Price  Moving_Minimum  VolumePositive
# 0  1672.212524  1475056            NaN             NaN           False
# 1  1669.715210  1852089            NaN             NaN           False
# 2  1655.281006  1594089            NaN             NaN           False
# 3  1650.736084  1480087            NaN             NaN           False
# 4  1669.015991  2497931            NaN             NaN            True

# %%
from mpl_finance import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax1 = plt.subplot(2, 1, 1)
candlestick_ohlc(ax1,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax1.plot(df['Moving_Minimum'], color='orange')
ax1.xaxis_date()
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax1.grid(True, which='both')
ax1.minorticks_on()
ax1v = ax1.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
ax1v.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
ax1v.axes.yaxis.set_ticklabels([])
ax1v.set_ylim(0, 3*df.Volume.max())
ax1.set_title('Stock '+ symbol +' Closing Price')
ax1.set_ylabel('Price')
ax1.legend()

ax2 = plt.subplot(2, 1, 2)
df['VolumePositive'] = df['Open'] < df['Adj Close']
ax2.bar(df.index, df['Volume'], color=df.VolumePositive.map({True: 'g', False: 'r'}), label='macdhist')
ax2.grid()
ax2.set_ylabel('Volume')
ax2.set_xlabel('Date')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'Date')
